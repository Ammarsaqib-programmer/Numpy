# %%
import numpy as np

# %%
oneDarray = np.array([1, 2, 3, 4, 5])
print(oneDarray)
# Out:
# [1 2 3 4 5]

# %%
twoDarray = np.array([[1, 2, 3], [4, 5, 6]])
print(twoDarray)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
threeDarray = np.array([
    [[1, 2, 3], [4, 5, 6]],
    [[-1, -2, -3], [-4, 5, -10]]
])
print(threeDarray)
# Out:
# [[[  1   2   3]
#   [  4   5   6]]
#
#  [[ -1  -2  -3]
#   [ -4   5 -10]]]

# %%
twoDarray = np.array([[1, 2, 3], [4, 5, 6]])
for i in twoDarray:
    print (i)
# Out:
# [1 2 3]
# [4 5 6]

# %%
for i in twoDarray:
    for j in i:
        print (j)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in threeDarray:
    print(i)
# Out:
# [[1 2 3]
#  [4 5 6]]
# [[ -1  -2  -3]
#  [ -4   5 -10]]

# %%
for i in threeDarray:
    for j in i:
        print (j)
# Out:
# [1 2 3]
# [4 5 6]
# [-1 -2 -3]
# [ -4   5 -10]

# %%
for i in threeDarray:
    for j in i:
        for k in j:
            print (k)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# -1
# -2
# -3
# -4
# 5
# -10
